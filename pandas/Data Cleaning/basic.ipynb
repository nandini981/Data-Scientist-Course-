# %%
import pandas as pd

# %%
s = pd.Series([12,2,32,4,35,43])

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
print(s)
# Out:
# 0    12
# 1     2
# 2    32
# 3     4
# 4    35
# 5    43
# dtype: int64

# %%
s2 = pd.Series([12,3,24,3,544,54,23,21],index=["harry","heered","jerry","maert","same","sad","wert","dsx"])

# %%
print(s2)
# Out:
# harry      12
# heered      3
# jerry      24
# maert       3
# same      544
# sad        54
# wert       23
# dsx        21
# dtype: int64

# %%
s2["harry"]
# Out:
# np.int64(12)

# %%
data = {
    "name" : ["alice", "bob","charlie"],
    "age" : [24,32,34],
    "city": ["delhi","mumbai","Banglore"]
}

# %%
data
# Out:
# {'name': ['alice', 'bob', 'charlie'],
#  'age': [24, 32, 34],
#  'city': ['delhi', 'mumbai', 'Banglore']}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#       name  age      city
# 0    alice   24     delhi
# 1      bob   32    mumbai
# 2  charlie   34  Banglore

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns
# Out:
# Index(['name', 'age', 'city'], dtype='object')

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4644\3618025248.py in ?()
# ----> 1 df.row
#
# c:\Users\nandi\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'row'
