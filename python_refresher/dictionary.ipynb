# %% [markdown]
# # Dictionary & Dictionary Methods

# %% [markdown]
# A dictionary in Python is an unordered, mutable, and key-value pair collection. It allows efficient data retrieval and modification. Dictionaries in Python are ordered as of Python 3.7

# %%
# Empty dictionary
empty_dict = {}

# Dictionary with key-value pairs
student = {
    "name": "Alice",
    "age": 25,
    "grade": "A"
}

# Using dict() constructor
person = dict(name="John", age=30, city="New York")

# %%
empty_dict, student, person
# Out:
# ({},
#  {'name': 'Alice', 'age': 25, 'grade': 'A'},
#  {'name': 'John', 'age': 30, 'city': 'New York'})

# %%
# Using keys
print(student["name"])  # Alice

# Using get() (avoids KeyError if key doesn't exist)
print(student.get("age"))  # 25
print(student.get("height", "Not Found"))  # Default value
# Out:
# Alice
# 25
# Not Found

# %%
print((student["name"], student["age"], student["grade"]))
# Out:
# ('Alice', 25, 'A')

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'grade'])

# %%
student.values()
# Out:
# dict_values(['Alice', 25, 'A'])

# %%
lst = student.items()
lst
# Out:
# dict_items([('name', 'Alice'), ('age', 25), ('grade', 'A')])

# %%
dict2 = {"city": "New York", "age": 30, "name": "John"}
dict2
# Out:
# {'city': 'New York', 'age': 30, 'name': 'John'}

# %%
student.update([("age", 26), ("grade", "A+")])

# %%
student
# Out:
# {'name': 'John', 'age': 26, 'grade': 'A+', 'city': 'New York'}

# %%
student.pop("grade")
# Out:
# 'A+'

# %%
student
# Out:
# {'name': 'John', 'age': 26, 'city': 'New York'}

# %%
student.popitem()
# Out:
# ('city', 'New York')

# %%
student
# Out:
# {'name': 'John', 'age': 26}
