# %%
#strings

# %%
name = "Nandini Saini"
name
type(name)
# Out:
# str

# %%
name.upper()
# Out:
# 'NANDINI SAINI'

# %%
name.capitalize()
# Out:
# 'Nandini saini'

# %%
name
# Out:
# 'Nandini Saini'

# %%
name.count("i")
# Out:
# 4

# %%
len(name)
# Out:
# 13

# %%
name.casefold()
# Out:
# 'nandini saini'

# %%
name.center(10)
# Out:
# 'Nandini Saini'

# %%
name.encode()
# Out:
# b'Nandini Saini'

# %%
name[0]
# Out:
# 'N'

# %%
name[0:4]
# Out:
# 'Nand'

# %%
name[1:-1]
# Out:
# 'andini Sain'

# %%
name[0:-1]
# Out:
# 'Nandini Sain'

# %%
name[0:-2]
# Out:
# 'Nandini Sai'

# %%
name[0::2]
# Out:
# 'NniiSii'

# %%
name[3:]
# Out:
# 'dini Saini'

# %%
name.strip("i")
# Out:
# 'Nandini Sain'

# %%
name.replace("Nandini", "Ankita")
# Out:
# 'Ankita Saini'

# %%
lst = name.split(" ")
lst
# Out:
# ['Nandini', 'Saini']

# %%
name.find("Saini")
# Out:
# 8

# %%
name.startswith("Nan")
# Out:
# True

# %%
name.endswith("ini")
# Out:
# True

# %%
name.endswith("jini")
# Out:
# False

# %%
name.isdigit()
# Out:
# False

# %%
name.isalpha()
# Out:
# False

# %%
name.isalpha()
# Out:
# False

# %%
"-".join(lst)
# Out:
# 'Nandini-Saini'

# %%
age = "25"

# %%
f"Hello, my name is {name} and I am {age} years old."
# Out:
# 'Hello, my name is Nandini Saini and I am 25 years old.'
