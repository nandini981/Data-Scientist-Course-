# %%
a = 5

# %%
b = 32

# %%
C = a + b

# %%
C
# Out:
# 37

# %%
name = "Nandini"

# %%
name
# Out:
# 'Nandini'

# %%
# this is a comment

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
is_student = True
print(type(is_student))
# Out:
# <class 'bool'>

# %%
is_student
# Out:
# True

# %%
lst = [1, 2, 3, 4, 5]

# %%
lst
# Out:
# [1, 2, 3, 4, 5]

# %%
print(type(lst))
# Out:
# <class 'list'>

# %%
lt = list("abc")

# %%
lt
# Out:
# ['a', 'b', 'c']

# %%
#typecasting examples
d = "123"
e = "334"
f = d+e

# %%
f
# Out:
# '123334'

# %%
print(int(d) + int(e))
# Out:
# 457
