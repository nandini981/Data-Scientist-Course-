# %%
#arithmetic_operations

# %%
a = 4
b = 2
a+b
# Out:
# 6

# %%
a-b
# Out:
# 2

# %%
a*b
# Out:
# 8

# %%
a/b
# Out:
# 2.0

# %%
a//b
# Out:
# 2

# %%
a**b
# Out:
# 16

# %%
a%b
# Out:
# 0

# %%
#Comparison Operators

# %%
a==b
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
a>b
# Out:
# True

# %%
a<b
# Out:
# False

# %%
a>=b
# Out:
# True

# %%
a>=b
# Out:
# True

# %%
#Logical Operators

# %%
a and b
# Out:
# 2

# %%
a or b
# Out:
# 4

# %%
f = True

# %%
g = False

# %%
f and g
# Out:
# False

# %%
f or g
# Out:
# True

# %%
not f
# Out:
# False

# %%
not g
# Out:
# True

# %%
a & b #bitwise and
# Out:
# 0

# %%
a | b #bitwise or
# Out:
# 6

# %%
#Assignment Operators
c = 5
c += 2
c -= 2
c *= 2
c /= 2
c %= 2
c **= 2
c //= 2
c
# Out:
# 0.0

# %%
c = 5

# %%
c += 2
c
# Out:
# 7

# %%
c -= 2
c
# Out:
# 5

# %%
c *= 2

# %%
c
# Out:
# 10

# %%
c/=2

# %%
c
# Out:
# 5.0

# %%
c//=2

# %%
c
# Out:
# 2.0

# %%
c%=2

# %%
c
# Out:
# 0.0

# %%
c**=2

# %%
c
# Out:
# 0.0

# %%
c = 10

# %%
c**=2

# %%
c
# Out:
# 100

# %%
#Membership & Identity Operators

# %%
lst=[1,2,3]

# %%
x=2

# %%
x in lst
# Out:
# True

# %%
x not in lst
# Out:
# False

# %%
x is lst
# Out:
# False

# %%
x is not lst
# Out:
# True

# %%
lst is not x
# Out:
# True

# %%
lst[1] is x
# Out:
# True
