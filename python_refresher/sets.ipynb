# %% [markdown]
# # Sets & Set Methods
# A set in Python is an unordered, mutable, and unique collection of elements. It does not allow duplicate values.

# %%
# Empty set (must use set(), not {})
empty_set = set()

# Set with elements
numbers = {1, 2, 3, 4, 5}

# Mixed data types
mixed_set = {1, "Hello", 3.14, True}

# Creating a set from a list
unique_numbers = set([1, 2, 2, 3, 4, 4, 5])
print(unique_numbers)  # {1, 2, 3, 4, 5}
# Out:
# {1, 2, 3, 4, 5}

# %%
numbers.add(6)

# %%
numbers
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
numbers.update([7, 8, 9])

# %%
numbers
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
numbers.remove(3)  # Raises KeyError if 3 is not found

# %%
numbers
# Out:
# {1, 2, 4, 5, 6, 7, 8, 9}

# %%
numbers.discard(10)  # Does not raise an error if 10 is not found

# %%
numbers
# Out:
# {1, 2, 4, 5, 6, 7, 8, 9}

# %%
numbers.discard(9)  # Does not raise an error if 10 is not found

# %%
numbers
# Out:
# {1, 2, 4, 5, 6, 7, 8}

# %%
numbers.pop()
# Out:
# 1

# %%
numbers
# Out:
# {2, 4, 5, 6, 7, 8}

# %%
new_num = numbers.copy()

# %%
new_num
# Out:
# {2, 4, 5, 6, 7, 8}

# %%
new_num.clear()

# %%
new_num
# Out:
# set()

# %% [markdown]
# # Set Operations

# %%
set2 = {4, 5, 6, 7, 8}

# %%
numbers.union(set2)
# Out:
# {2, 4, 5, 6, 7, 8}

# %%
numbers.intersection(set2)
# Out:
# {4, 5, 6, 7, 8}

# %%
numbers
# Out:
# {2, 4, 5, 6, 7, 8}

# %%
set2
# Out:
# {4, 5, 6, 7, 8}

# %%
numbers.difference(set2)
# Out:
# {2}

# %%
numbers.symmetric_difference(set2)
# Out:
# {2}

# %%
set2.issubset(numbers)
# Out:
# True

# %%
numbers.issuperset(set2)
# Out:
# True

# %%
set2.issuperset(numbers)
# Out:
# False

# %%
set1 = {1, 2, 3, 4}
set2 = {3, 4, 5, 6}

# Union – combines all unique elements
print(set1 | set2)            # {1, 2, 3, 4, 5, 6}
print(set1.union(set2))       # same result

# Intersection – common elements
print(set1 & set2)            # {3, 4}
print(set1.intersection(set2))# same result

# Difference – in set1 but not in set2
print(set1 - set2)            # {1, 2}
print(set1.difference(set2))  # same result

# Symmetric Difference – in either set, but not both
print(set1 ^ set2)                     # {1, 2, 5, 6}
print(set1.symmetric_difference(set2))# same result
# Out:
# {1, 2, 3, 4, 5, 6}
# {1, 2, 3, 4, 5, 6}
# {3, 4}
# {3, 4}
# {1, 2}
# {1, 2}
# {1, 2, 5, 6}
# {1, 2, 5, 6}

# %% [markdown]
# # Key Properties of Sets:
#
# *Unordered:* No indexing or slicing.
#
# *Unique Elements:* Duplicates are automatically removed.
#
# *Mutable*: You can add or remove elements.
