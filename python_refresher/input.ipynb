# %%
name = input("Enter your name: ")

# %%
print("Hello, " + name + "!")
# Out:
# Hello, Nandini!

# %%
age = int(input("Enter your age: "))
age
# Out:
# 17

# %%
price = float(input("Enter the price of the item: "))
price
print("The price of the item is $" + str(price))
# Out:
# The price of the item is $120.0

# %%
print(int(age) + int(price))
# Out:
# 137
